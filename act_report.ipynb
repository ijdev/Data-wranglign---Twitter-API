# %% [markdown]
# # Analysis & visualization Report
#  In the data we have collected and cleaned we will be able to answer these questions and visualize the result.
#    - Which Dog stage gets more retweets or Likes "favorites”?
#    - What is the most popular dog prediction?
#    - Which dog breed is the most dominate in retweets?

# %% [markdown]
# ### Which Dog stage gets more retweets or Likes "favorites”?
# > To answer the first question, we must analyze the stage column and the result we got is the pupper stage is the most liked and retweeted stage follows it the doggo stage, and the rest are way below these two as the figure below shows.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What is the most popular dog prediction?
# >The second question tackles the image prediction and to see what the most repeated prediction of dog’s breed. The result was the golden retriever is in a tie with Labrador retriever and in third is chihuahua, and in last is Pekinese with 62 of time to be predicted. See below figure.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Which dog breed is the most dominate in retweets?
# >The third question is asking what is the most retweeted dog breed? This question was not easy to answer we had to some do data manipulation to get the breed of each dog and then count the retweets of each breed. As expected in the below figure, the first two are the golden retriever and Labrador retriever, but even so the prediction was a tie in the previous figure, the Golden retriever is way ahead of the Labrador retriever. The third and fourth result is also interesting, the third result was the fourth in the previous figure and fourth was the third.

# %% [markdown]
# ![image.png](attachment:image.png)
